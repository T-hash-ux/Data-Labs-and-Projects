# %% [markdown]
# # Database Admin 101 - Lab
#
# ## Introduction
#
# In this lab, you'll go through the process of designing and creating a database. From there, you'll begin to populate this table with mock data provided to you.
#
# ## Objectives
#
# You will be able to:
#
# * Use knowledge of the structure of databases to create a database and populate it

# %% [markdown]
# ## The Scenario
#
# You are looking to design a database for a school that will house various information from student grades to contact information, class roster lists and attendance. First, think of how you would design such a database. What tables would you include? What columns would each table have? What would be the primary means to join said tables?

# %% [markdown]
# ## Creating the Database
#
# Now that you've put a little thought into how you might design your database, it's time to go ahead and create it! Start by import the necessary packages. Then, create a database called **school.sqlite**.

# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.Connection('school.sqlite')

# %% [markdown]
# ## Create a Table for Contact Information
#
# Create a table called contactInfo to house contact information for both students and staff. Be sure to include columns for first name, last name, role (student/staff), telephone number, street, city, state, and zipcode. Be sure to also create a primary key for the table.

# %%
cur = conn.cursor()
cur.execute("""CREATE TABLE contactInfo (
                                        userId INTEGER PRIMARY KEY,
                                        firstName TEXT,
                                        lastName TEXT,
                                        role TEXT,
                                        telephone INTEGER,
                                        street TEXT,
                                        city TEXT,
                                        state TEXT,
                                        zipcode TEXT
                                        );
            """)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /tmp/ipykernel_47/4028499653.py in <module>
#       1 cur = conn.cursor()
# ----> 2 cur.execute("""CREATE TABLE contactInfo (
#       3                                         userId INTEGER PRIMARY KEY,
#       4                                         firstName TEXT,
#       5                                         lastName TEXT,
#
# OperationalError: table contactInfo already exists

# %% [markdown]
# ## Populate the Table
#
# Below, code is provided for you in order to load a list of dictionaries. Briefly examine the list. Each dictionary in the list will serve as an entry for your contact info table. Once you've briefly investigated the structure of this data, write a for loop to iterate through the list and create an entry in your table for each person's contact info.

# %%
# Load the list of dictionaries; just run this cell
import pickle

with open('contact_list.pickle', 'rb') as f:
    contacts = pickle.load(f)

# %%
for contact in contacts:
    firstName = contact['firstName']
    lastName = contact['lastName']
    role = contact['role']
    telephone  = contact['telephone ']
    street = contact['street']
    city = contact['city']
    state = contact['state']
    zipcode  = contact['zipcode ']
    cur.execute("""INSERT INTO contactInfo (firstName, lastName, role, telephone, street, city, state, zipcode) 
                  VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');
                """.format(firstName, lastName, role, telephone, street, city, state, zipcode) )

# %% [markdown]
# **Query the Table to Ensure it is populated**

# %%
cur.execute("""SELECT * 
               FROM contactInfo;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#     userId    firstName  lastName     role   telephone  \
# 0        1    Christine    Holden    staff  2035687697
# 1        2  Christopher    Warren  student  2175150957
# 2        3        Linda  Jacobson    staff  4049446441
# 3        4       Andrew     Stepp  student  7866419252
# 4        5         Jane     Evans  student  3259909290
# 5        6         Jane     Evans  student  3259909290
# 6        7         Mary    Raines  student  9075772295
# 7        8           Ed     Lyman  student  5179695576
# 8        9    Christine    Holden    staff  2035687697
# 9       10  Christopher    Warren  student  2175150957
# 10      11        Linda  Jacobson    staff  4049446441
# 11      12       Andrew     Stepp  student  7866419252
# 12      13         Jane     Evans  student  3259909290
# 13      14         Jane     Evans  student  3259909290
# 14      15         Mary    Raines  student  9075772295
# 15      16           Ed     Lyman  student  5179695576
# 16      17    Christine    Holden    staff  2035687697
# 17      18  Christopher    Warren  student  2175150957
# 18      19        Linda  Jacobson    staff  4049446441
# 19      20       Andrew     Stepp  student  7866419252
# 20      21         Jane     Evans  student  3259909290
# 21      22         Jane     Evans  student  3259909290
# 22      23         Mary    Raines  student  9075772295
# 23      24           Ed     Lyman  student  5179695576
# 24      25    Christine    Holden    staff  2035687697
# 25      26  Christopher    Warren  student  2175150957
# 26      27        Linda  Jacobson    staff  4049446441
# 27      28       Andrew     Stepp  student  7866419252
# 28      29         Jane     Evans  student  3259909290
# 29      30         Jane     Evans  student  3259909290
# 30      31         Mary    Raines  student  9075772295
# 31      32           Ed     Lyman  student  5179695576
# 32      33    Christine    Holden    staff  2035687697
# 33      34  Christopher    Warren  student  2175150957
# 34      35        Linda  Jacobson    staff  4049446441
# 35      36       Andrew     Stepp  student  7866419252
# 36      37         Jane     Evans  student  3259909290
# 37      38         Jane     Evans  student  3259909290
# 38      39         Mary    Raines  student  9075772295
# 39      40           Ed     Lyman  student  5179695576
#
#                        street       city state zipcode
# 0          1672 Whitman Court   Stamford    CT   06995
# 1   1935 University Hill Road  Champaign    IL   61938
# 2         479 Musgrave Street    Atlanta    GA   30303
# 3   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 4         1461 Briarhill Lane    Abilene    TX   79602
# 5         1461 Briarhill Lane    Abilene    TX   79602
# 6       3975 Jerry Toth Drive  Ninilchik    AK   99639
# 7               3478 Be Sreet    Lansing    MI   48933
# 8          1672 Whitman Court   Stamford    CT   06995
# 9   1935 University Hill Road  Champaign    IL   61938
# 10        479 Musgrave Street    Atlanta    GA   30303
# 11  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 12        1461 Briarhill Lane    Abilene    TX   79602
# 13        1461 Briarhill Lane    Abilene    TX   79602
# 14      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 15              3478 Be Sreet    Lansing    MI   48933
# 16         1672 Whitman Court   Stamford    CT   06995
# 17  1935 University Hill Road  Champaign    IL   61938
# 18        479 Musgrave Street    Atlanta    GA   30303
# 19  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 20        1461 Briarhill Lane    Abilene    TX   79602
# 21        1461 Briarhill Lane    Abilene    TX   79602
# 22      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 23              3478 Be Sreet    Lansing    MI   48933
# 24         1672 Whitman Court   Stamford    CT   06995
# 25  1935 University Hill Road  Champaign    IL   61938
# 26        479 Musgrave Street    Atlanta    GA   30303
# 27  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 28        1461 Briarhill Lane    Abilene    TX   79602
# 29        1461 Briarhill Lane    Abilene    TX   79602
# 30      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 31              3478 Be Sreet    Lansing    MI   48933
# 32         1672 Whitman Court   Stamford    CT   06995
# 33  1935 University Hill Road  Champaign    IL   61938
# 34        479 Musgrave Street    Atlanta    GA   30303
# 35  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 36        1461 Briarhill Lane    Abilene    TX   79602
# 37        1461 Briarhill Lane    Abilene    TX   79602
# 38      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 39              3478 Be Sreet    Lansing    MI   48933

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Persist your changes by committing them to the database.

# %%
conn.commit()

# %% [markdown]
# ## Create a Table for Student Grades
#
# Create a new table in the database called "grades". In the table, include the following fields: userId, courseId, grade.
#
# ** This problem is a bit more tricky and will require a dual key. (A nuance you have yet to see.)
# Here's how to do that:
#
# ```SQL
# CREATE TABLE table_name(
#    column_1 INTEGER NOT NULL,
#    column_2 INTEGER NOT NULL,
#    ...
#    PRIMARY KEY(column_1,column_2,...)
# );
# ```

# %%
cur.execute("""CREATE TABLE grades (
                                    userId INTEGER NOT NULL,
                                    courseId INTEGER NOT NULL,
                                    grade INTEGER,
                                    PRIMARY KEY(userId, courseId)
                                    );
            """)

# %% [markdown]
# ## Remove Duplicate Entries
#
# An analyst just realized that there is a duplicate entry in the contactInfo table! Find and remove it.

# %%
cur.execute("""SELECT firstName, lastName, telephone, COUNT(*)
                FROM contactInfo
                GROUP BY firstName, lastName, telephone
                HAVING COUNT(*) > 1;"""). fetchall()
# Out:
# [('Andrew', 'Stepp', 7866419252, 2),
#  ('Christine', 'Holden', 2035687697, 2),
#  ('Christopher', 'Warren', 2175150957, 2),
#  ('Ed', 'Lyman', 5179695576, 2),
#  ('Jane', 'Evans', 3259909290, 4),
#  ('Linda', 'Jacobson', 4049446441, 2),
#  ('Mary', 'Raines', 9075772295, 2)]

# %%
cur.execute("""DELETE FROM contactInfo 
               WHERE telephone = 3259909290;""")

# %%
cur.execute("""SELECT firstName, lastName, telephone, COUNT(*) 
               FROM contactInfo
               GROUP BY firstName, lastName, telephone
               HAVING COUNT(*) > 1;""").fetchall()
# Out:
# [('Andrew', 'Stepp', 7866419252, 2),
#  ('Christine', 'Holden', 2035687697, 2),
#  ('Christopher', 'Warren', 2175150957, 2),
#  ('Ed', 'Lyman', 5179695576, 2),
#  ('Linda', 'Jacobson', 4049446441, 2),
#  ('Mary', 'Raines', 9075772295, 2)]

# %% [markdown]
# ## Updating an Address
#
# Ed Lyman just moved to `2910 Simpson Avenue York, PA 17403`. Update his address accordingly.

# %%
cur.execute("""UPDATE contactInfo
               SET street = "2910 Simpson Avenue",
                   city = 'York',
                   state = 'PA',
                   zipcode = '17403'
               WHERE firstName = "Ed" AND lastName = "Lyman";""")

# %%
cur.execute("""SELECT * 
               FROM contactInfo;""")
df = pd.DataFrame(cur.fetchall())
df.columns = [x[0] for x in cur.description]
df
# Out:
#     userId    firstName  lastName     role   telephone  \
# 0        1    Christine    Holden    staff  2035687697
# 1        2  Christopher    Warren  student  2175150957
# 2        3        Linda  Jacobson    staff  4049446441
# 3        4       Andrew     Stepp  student  7866419252
# 4        5         Jane     Evans  student  3259909290
# 5        6         Jane     Evans  student  3259909290
# 6        7         Mary    Raines  student  9075772295
# 7        8           Ed     Lyman  student  5179695576
# 8        9    Christine    Holden    staff  2035687697
# 9       10  Christopher    Warren  student  2175150957
# 10      11        Linda  Jacobson    staff  4049446441
# 11      12       Andrew     Stepp  student  7866419252
# 12      13         Jane     Evans  student  3259909290
# 13      14         Jane     Evans  student  3259909290
# 14      15         Mary    Raines  student  9075772295
# 15      16           Ed     Lyman  student  5179695576
# 16      17    Christine    Holden    staff  2035687697
# 17      18  Christopher    Warren  student  2175150957
# 18      19        Linda  Jacobson    staff  4049446441
# 19      20       Andrew     Stepp  student  7866419252
# 20      21         Jane     Evans  student  3259909290
# 21      22         Jane     Evans  student  3259909290
# 22      23         Mary    Raines  student  9075772295
# 23      24           Ed     Lyman  student  5179695576
# 24      25    Christine    Holden    staff  2035687697
# 25      26  Christopher    Warren  student  2175150957
# 26      27        Linda  Jacobson    staff  4049446441
# 27      28       Andrew     Stepp  student  7866419252
# 28      29         Jane     Evans  student  3259909290
# 29      30         Jane     Evans  student  3259909290
# 30      31         Mary    Raines  student  9075772295
# 31      32           Ed     Lyman  student  5179695576
# 32      33    Christine    Holden    staff  2035687697
# 33      34  Christopher    Warren  student  2175150957
# 34      35        Linda  Jacobson    staff  4049446441
# 35      36       Andrew     Stepp  student  7866419252
# 36      37         Jane     Evans  student  3259909290
# 37      38         Jane     Evans  student  3259909290
# 38      39         Mary    Raines  student  9075772295
# 39      40           Ed     Lyman  student  5179695576
#
#                        street       city state zipcode
# 0          1672 Whitman Court   Stamford    CT   06995
# 1   1935 University Hill Road  Champaign    IL   61938
# 2         479 Musgrave Street    Atlanta    GA   30303
# 3   2981 Lamberts Branch Road    Hialeah    Fl   33012
# 4         1461 Briarhill Lane    Abilene    TX   79602
# 5         1461 Briarhill Lane    Abilene    TX   79602
# 6       3975 Jerry Toth Drive  Ninilchik    AK   99639
# 7         2910 Simpson Avenue       York    PA   17403
# 8          1672 Whitman Court   Stamford    CT   06995
# 9   1935 University Hill Road  Champaign    IL   61938
# 10        479 Musgrave Street    Atlanta    GA   30303
# 11  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 12        1461 Briarhill Lane    Abilene    TX   79602
# 13        1461 Briarhill Lane    Abilene    TX   79602
# 14      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 15        2910 Simpson Avenue       York    PA   17403
# 16         1672 Whitman Court   Stamford    CT   06995
# 17  1935 University Hill Road  Champaign    IL   61938
# 18        479 Musgrave Street    Atlanta    GA   30303
# 19  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 20        1461 Briarhill Lane    Abilene    TX   79602
# 21        1461 Briarhill Lane    Abilene    TX   79602
# 22      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 23        2910 Simpson Avenue       York    PA   17403
# 24         1672 Whitman Court   Stamford    CT   06995
# 25  1935 University Hill Road  Champaign    IL   61938
# 26        479 Musgrave Street    Atlanta    GA   30303
# 27  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 28        1461 Briarhill Lane    Abilene    TX   79602
# 29        1461 Briarhill Lane    Abilene    TX   79602
# 30      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 31        2910 Simpson Avenue       York    PA   17403
# 32         1672 Whitman Court   Stamford    CT   06995
# 33  1935 University Hill Road  Champaign    IL   61938
# 34        479 Musgrave Street    Atlanta    GA   30303
# 35  2981 Lamberts Branch Road    Hialeah    Fl   33012
# 36        1461 Briarhill Lane    Abilene    TX   79602
# 37        1461 Briarhill Lane    Abilene    TX   79602
# 38      3975 Jerry Toth Drive  Ninilchik    AK   99639
# 39        2910 Simpson Avenue       York    PA   17403

# %% [markdown]
# ## Commit Your Changes to the Database
#
# Once again, persist your changes by committing them to the database.

# %%
conn.commit()

# %% [markdown]
# ## Summary
#
# While there's certainly more to do with setting up and managing this database, you got a taste for creating, populating, and maintaining databases! Feel free to continue fleshing out this exercise for more practice.
